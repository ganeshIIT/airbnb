# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshIIT/airbnb/blob/master/airbnb_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyodbc -q

# !curl https://packages.microsoft.com/keys/microsoft.asc | apt-key add -
# !curl https://packages.microsoft.com/config/ubuntu/16.04/prod.list > /etc/apt/sources.list.d/mssql-release.list
# !sudo apt-get update
# !sudo ACCEPT_EULA=Y apt-get -q -y install msodbcsql17

# %%
import re

import numpy as np
import pandas as pd
import pyodbc

import helper
import dataloader

# %%
cstring = helper.get_connstring()
with pyodbc.connect(cstring) as conn:
    query = "SELECT * from listings"
    df = pd.read_sql(query, conn, index_col='id')

df
# Out:
# /var/folders/74/ndv7v28d3078l2cq22t43pkc0000gn/T/ipykernel_64670/633396159.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn, index_col='id')
#                 listing_id        country province           city  \
# id
# 1                   108061  united-states       nc      asheville
# 2                   155305  united-states       nc      asheville
# 3                   156805  united-states       nc      asheville
# 4                   156926  united-states       nc      asheville
# 5                   197263  united-states       nc      asheville
# ...                    ...            ...      ...            ...
# 274786  559604746999427599  united-states       dc  washington-dc
# 274787            50244048  united-states       dc  washington-dc
# 274788            38149408  united-states       dc  washington-dc
# 274789            18854142  united-states       dc  washington-dc
# 274790            29562913  united-states       dc  washington-dc
#
#                                             listing_url           source  \
# id
# 1                   https://www.airbnb.com/rooms/108061      city scrape
# 2                   https://www.airbnb.com/rooms/155305      city scrape
# 3                   https://www.airbnb.com/rooms/156805  previous scrape
# 4                   https://www.airbnb.com/rooms/156926      city scrape
# 5                   https://www.airbnb.com/rooms/197263      city scrape
# ...                                                 ...              ...
# 274786  https://www.airbnb.com/rooms/559604746999427599      city scrape
# 274787            https://www.airbnb.com/rooms/50244048      city scrape
# 274788            https://www.airbnb.com/rooms/38149408      city scrape
# 274789            https://www.airbnb.com/rooms/18854142      city scrape
# 274790            https://www.airbnb.com/rooms/29562913      city scrape
#
#                                                      name    host_id  \
# id
# 1       Walk to stores/parks/downtown. Fenced yard/Pet...     320564
# 2                      Cottage! BonPaul + Sharky's Hostel     746673
# 3                       Private Room "Ader" at BPS Hostel     746673
# 4                  Mixed Dorm "Top Bunk #1" at BPS Hostel     746673
# 5                            Tranquil Room & Private Bath     961396
# ...                                                   ...        ...
# 274786       Central & cozy studio steps to Rosslyn metro    7171650
# 274787     Large One-Bedroom with Private Balcony Near DC  376315368
# 274788  Luxury brand-new home mins away from Washingto...  224988072
# 274789                               Luxury Condo Rosslyn  131341460
# 274790     Beautiful Upgraded Studio with Porcelain Floor    6586687
#
#             host_name  host_since  ... review_scores_communication  \
# id                                 ...
# 1                Lisa  2010-12-16  ...                        4.79
# 2             BonPaul  2011-06-26  ...                        4.74
# 3             BonPaul  2011-06-26  ...                        4.61
# 4             BonPaul  2011-06-26  ...                        4.80
# 5                Timo  2011-08-12  ...                        4.92
# ...               ...         ...  ...                         ...
# 274786  Lily & Szymon  2013-06-28  ...                        5.00
# 274787          Amber  2020-11-19  ...                        5.00
# 274788          Thang  2018-11-09  ...                        4.99
# 274789         Claire  2017-05-21  ...                        4.97
# 274790         Bonnie  2013-05-26  ...                        5.00
#
#        review_scores_location review_scores_value license  instant_bookable  \
# id
# 1                        4.84                4.48    None             False
# 2                        4.93                4.54    None              True
# 3                        4.84                4.46    None              True
# 4                        4.79                4.79    None              True
# 5                        4.82                4.98    None             False
# ...                       ...                 ...     ...               ...
# 274786                   5.00                5.00    None             False
# 274787                   5.00                4.00    None             False
# 274788                   4.99                4.81    None             False
# 274789                   4.92                4.85    None              True
# 274790                   5.00                5.00    None             False
#
#         calculated_host_listings_count  \
# id
# 1                                    2
# 2                                    7
# 3                                    7
# 4                                    7
# 5                                    2
# ...                                ...
# 274786                               2
# 274787                              31
# 274788                               1
# 274789                               1
# 274790                               6
#
#         calculated_host_listings_count_entire_homes  \
# id
# 1                                                 2
# 2                                                 1
# 3                                                 1
# 4                                                 1
# 5                                                 1
# ...                                             ...
# 274786                                            2
# 274787                                           31
# 274788                                            1
# 274789                                            1
# 274790                                            6
#
#        calculated_host_listings_count_private_rooms  \
# id
# 1                                                 0
# 2                                                 2
# 3                                                 2
# 4                                                 2
# 5                                                 1
# ...                                             ...
# 274786                                            0
# 274787                                            0
# 274788                                            0
# 274789                                            0
# 274790                                            0
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 1                                                 0               0.67
# 2                                                 4               2.72
# 3                                                 4               0.50
# 4                                                 4               2.34
# 5                                                 0               0.49
# ...                                             ...                ...
# 274786                                            0               0.94
# 274787                                            0               0.15
# 274788                                            0               2.25
# 274789                                            0               0.64
# 274790                                            0               0.21
#
# [274790 rows x 56 columns]

# %%
df.nunique().sort_values()
# Out:
# country                                              1
# host_is_superhost                                    2
# has_availability                                     2
# host_has_profile_pic                                 2
# host_identity_verified                               2
# instant_bookable                                     2
# source                                               2
# room_type                                            4
# host_response_time                                   4
# host_verifications                                  10
# accommodates                                        17
# calendar_last_scraped                               18
# province                                            19
# bedrooms                                            23
# calculated_host_listings_count_shared_rooms         31
# city                                                31
# availability_30                                     31
# beds                                                42
# number_of_reviews_l30d                              58
# availability_60                                     61
# bathrooms_text                                      68
# calculated_host_listings_count_private_rooms        75
# host_response_rate                                  89
# availability_90                                     91
# host_acceptance_rate                               101
# property_type                                      136
# calculated_host_listings_count_entire_homes        166
# calculated_host_listings_count                     177
# minimum_nights                                     179
# review_scores_checkin                              187
# review_scores_communication                        191
# review_scores_accuracy                             197
# review_scores_rating                               200
# review_scores_location                             201
# review_scores_value                                205
# review_scores_cleanliness                          221
# number_of_reviews_ltm                              288
# availability_365                                   366
# host_listings_count                                414
# host_total_listings_count                          499
# number_of_reviews                                  840
# reviews_per_month                                 1437
# price                                             2715
# last_review                                       2966
# host_location                                     4244
# first_review                                      4344
# host_since                                        4938
# host_name                                        33007
# license                                          48063
# host_id                                         135706
# latitude                                        192031
# longitude                                       195199
# amenities                                       243296
# name                                            263621
# listing_url                                     274790
# listing_id                                      274790
# dtype: int64

# %%
df['reviews_per_month'].describe()
# Out:
# count    223769.000000
# mean          1.706585
# std           2.006504
# min           0.010000
# 25%           0.340000
# 50%           1.050000
# 75%           2.500000
# max         190.480000
# Name: reviews_per_month, dtype: float64

# %%
df['reviews_per_month'].median()
# Out:
# 1.05
